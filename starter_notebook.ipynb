# %% [markdown]
# <a href="https://colab.research.google.com/github/Princess-royaL100/smart-finance-assistant-/blob/main/starter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏦 THE LIFESTYLE ARCHITECT
#
# University students often struggle to maintain a budget because their income is irregular. Part-time work, casual shifts, or allowances and their expenses are highly variable textbooks at the start of the semester, weekly transit, social events, and food. Without clear visibility, students frequently overspend in social categories and run out of money for essential living expenses. The lifestyle architect solves this by letting students bank CSV export.
#
# ## **Step 2 ** Inputs and Outputs
#
# Inputs:
# - CSV Data file
# - Monthly Income Target
# - Saving Goal
#
# Outputs:
#
# - Financial Summary Dashboard:
# - Category Breakdown
# - The Lifestyle Budget Alert
#
# UPDATE OF THE INPUTS AND OUTPUTS
#
# INPUTS
# - CSV Data File: Bank statement containing columns for Date, Amount, Category, and Description.
# - Monthly Income Target: A manual text input from the user stating their total expected income for the month.
# Savings Goal: The amount of money they want to save this month.
#
# OUTPUTS
# - Financial Summary Dashboard: Clean, formatted total spending, total savings/refunds, and net balance.
# Category Breakdown: A breakdown showing exactly how much was spent on Groceries, Entertainment, Transport, etc.
# - The "Lifestyle Budget Alert": A warning text if non-essential spending exceeds 50% of their total outlays.
#
# ## **Step 3 ** WORK THE PROBLEM BY HAND
#
# CALCULATIONS
#
# Total Outflow = Sum of all individual positive transations
# Total inflow = Sum of all individual negetive transactions
# Net Expenses = Total Outflow - Total inflow
# Category Percentage = (Total Spent in one Category/Total Outflow)*100
# Average Transaction Amount = Total Money spent/Total Number of Transactions
#
# ## **STEP 4 ** PSEUDOCODE
#
# - Welcome the user
# - Check File Validity-
# IF no file uploaded THEN:
#    Return an error message saying "Please upload a valid CSV.
# - Read the Data
# Open and read the uploaded CSV file into a data table
# - Columns and validation
# IF columns named 'Date', 'Amount', 'Category', and 'Description' do not all exist THEN:
#  RETURN an error message saying "Invalid file format. Required columns are missing.
# - Data Transformation Loop
#     FOR each row in the data table:
#         Take the text inside the 'Amount' column
#         Strip out the dollar sign symbol ($) if it exists
#         Strip out any empty spaces, commas, or letters
#         Convert that cleaned text into a pure decimal number (float)
#         Update the 'Amount' cell with this clean number
#
# - Handle Missing Text Data
#     FOR each row in the data table:
#         IF the 'Category' cell or 'Description' cell is empty THEN:
#             Fill that empty cell with the text label "Uncategorized"
#
#     RETURN the fully cleaned and validated data table
#
#   Part 2- Pseudocode: Budgeting and Fomula Logic
#   1. Calculate Inflows and Outflows
#     Create a sub-list of all rows where the Amount number is greater than zero (Expenses)
#     Sum up all these positive numbers to calculate TOTAL OUTFLOW
#
#     Create a sub-list of all rows where the Amount number is less than zero (Refunds/Income)
#     Sum up all these negative numbers, ignoring their minus signs, to calculate TOTAL INFLOW
#
#     Calculate NET EXPENSES by subtracting TOTAL INFLOW from TOTAL OUTFLOW
#
#   2. Group by Category
#     Look at all unique names in the 'Category' column (e.g., Rent, Food, Transport)
#     For each unique category name:
#         Find all matching rows in the table
#         Sum up their cleaned Amount numbers to find the CATEGORY TOTAL
#
#   3. Calculate Habits Percentage
#     FOR each unique category name:
#         Divide its CATEGORY TOTAL by the overall TOTAL OUTFLOW
#         Multiply the result by 100 to calculate the CATEGORY PERCENTAGE
#
#     RETURN TOTAL OUTFLOW, TOTAL INFLOW, NET EXPENSES, and the grouped CATEGORY BREAKDOWN
#
# FUNCTION generate_financial_recommendations(total_outflow, net_expenses, category_breakdown):
# 1. Initialize the Report
#     Create an empty text block called STUDENT_REPORT
#     Add a friendly opening greeting: "Welcome to your Lifestyle Architect Budget Summary! 🏛️"
#
# 2. Find the Problem Area
#     Look at the category breakdown and identify which category has the highest total spending amount
#     Store this category name as TOP_CATEGORY
#
# 3. Evaluate Spending Habits against Student Benchmarks
#     IF net_expenses is greater than $1,500 THEN:
#         Add a warning message: "🚨 Alert: Your net spending is quite high for this period. Review your flexible lifestyle costs!"
#     ELSE IF net_expenses is between $500 and $1,500 THEN:
#         Add a steady message: "👍 Balanced: Your spending is within a healthy, moderate student budget range."
#     ELSE:
#         Add a praise message: "✨ Excellent Job: Your overall expenses are beautifully low. Keep up the great savings!"
#
#   4. Inject Category Specific Advice
#     Add a sentence to the report saying: "Your largest area of expense was TOP_CATEGORY."
#
#     IF TOP_CATEGORY is equal to "Food & Drink" or "Entertainment" THEN:
#         Add the tip: "💡 Strategy: Try tracking your campus cafe apps or meal-prepping to cut down on discretionary outlays."
#     ELSE IF TOP_CATEGORY is equal to "Rent" or "Bills" THEN:
#         Add the tip: "💡 Strategy: Your biggest outlays are fixed essentials. Focus on managing your smaller daily spending instead."
#     ELSE:
#         Add the tip: "💡 Strategy: Keep an eye on this category next week to ensure it doesn't grow into a habit."
#
#     RETURN the finalized STUDENT_REPORT text block
#
# ## **STEP 5 AND 6 FINAL CODE **

# %% [markdown]
# ---
#
# # 🚀 Getting Started: Foundation Setup
#
# ## Initial Setup
# import pandas as pd
# import numpy as np from datetime
# import warnings
#
# print("Core libraries loaded successfully!")

# %%
# Uncomment the line below when running in Google Colab
# !pip install gradio pandas hands-on-ai

# Import core libraries
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print("📦 Core libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")

# %%
# 🤖 AI Collaboration Prompt used: "Create a function to load a personal finance CSV transaction data with Date, Amount, Category, and Description columns.
# Handle Australian dollar signs, commas, and negative signs in the Amount column.
# If Category or Description are missing, fill them with 'Uncategorized'. Include clear, user-friendly error messages."

import pandas as pd
import numpy as np

def load_and_clean_transaction_data(file_path):
    """
    Loads and cleans student transaction data for The Lifestyle Architect tracker.
    Handles formatting issues like '$' symbols, missing values, and type conversions.
    """
    try:
        # Load the CSV file into a Pandas DataFrame
        # (file_path can be a string path or a Gradio file object)
        if isinstance(file_path, str):
            df = pd.read_csv(file_path)
        else:
            df = pd.read_csv(file_path.name)

        # 1. Validate Columns exist
        required_columns = ['Date', 'Amount', 'Category', 'Description']
        for col in required_columns:
            if col not in df.columns:
                raise ValueError(f"Missing required column: '{col}'. Please check your bank statement format.")

        # 2. Clean the 'Amount' column
        # Convert to string first to handle any mixed data types, then strip characters
        df['Amount'] = df['Amount'].astype(str).str.replace('$', '', regex=False)
        df['Amount'] = df['Amount'].str.replace(',', '', regex=False)
        df['Amount'] = df['Amount'].str.strip()

        # Convert to numeric float values
        df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

        # Drop rows where the Amount couldn't be parsed into a number
        df = df.dropna(subset=['Amount'])

        # 3. Handle Missing Text Values
        df['Category'] = df['Category'].fillna('Uncategorized').str.strip()
        df['Description'] = df['Description'].fillna('Unknown Merchant').str.strip()

        print("📊 Data successfully loaded and cleaned!")
        return df

    except Exception as e:
        print(f"❌ Error loading data: {e}")
        return None

# %% [markdown]
# ## Hands-on-AI Configuration
#
# Set up the hands-on-ai package for advanced features (chat, RAG, tools):

# %%
import os
# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.locollm.org'
os.environ['HANDS_ON_AI_MODEL'] = 'gemma3:4b'
os.environ['HANDS_ON_AI_API_KEY'] = 'Curtin2026ISYS20015002'
print("🔑 Hands-on-AI configured successfully!")

# %% [markdown]
# The API key this semester is:  **isys2001-assignment-key**

# %% [markdown]
# ## Connection Test
#
# Test that everything is working correctly:

# %%
from hands_on_ai.chat import get_response

# Test the connection to the hands-on-ai server
try:
    response = get_response("Hello! I'm building a Smart Finance Assistant.")
    print("✅ Hands-on-AI connection successful!")
    print(f"Response: {response}")
except Exception as e:
    print(f"❌ Connection issue: {e}")
    print("You can still work on the data processing foundation without this.")

# %% [raw]
# ---

# %%
# =====================================================================
# 🏰 THE LIFESTYLE ARCHITECT — COMPLETE FINANCIAL ANALYZER SYSTEM
# =====================================================================

# =====================================================================
# 📑 SAMPLE TRANSACTION DATA SETUP
# =====================================================================

print("📑 Generating sample transaction dataset...")
print("=" * 70)

messy_ledger_data = """Date,Amount,Category,Description
2026-03-01,$1200.00,Income,Part-time tutoring allowance
2026-03-02,450.00,Rent,Student Accommodation Fixed Weekly Pay
2026-03-03,$12.50,Groceries,Coles Supermarket purchase
2026-03-04,$6.80,Cafe,Campus Guild Cappuccino
2026-03-05,85.20,Utilities,Synergy Electricity Contribution
2026-03-06,$120.00,Entertainment,Concert Ticket booking
2026-03-07,$22.00,Transport,Transperth SmartRider Autoload
2026-03-08,,Food,Missing ledger item entry test case
"""

target_csv_filename = "student_bank_statement.csv"

with open(target_csv_filename, "w", encoding="utf-8") as csv_file:
    csv_file.write(messy_ledger_data.strip())

print(f"✅ CSV dataset saved successfully: {target_csv_filename}")

# =====================================================================
# ⚙️ FOUNDATION DATA PROCESSING FUNCTIONS
# =====================================================================

def load_and_sanitize_statement(file_path: str) -> Optional[pd.DataFrame]:

    try:

        if not os.path.exists(file_path):
            raise FileNotFoundError(f"File not found: {file_path}")

        df = pd.read_csv(file_path, skipinitialspace=True)

        required_schema = ['Date', 'Amount', 'Category', 'Description']

        if not all(col in df.columns for col in required_schema):
            raise KeyError(
                f"Dataset must contain: {required_schema}"
            )

        sanitized_df = df[required_schema].copy()

        # Clean Amount column
        sanitized_df['Amount'] = (
            sanitized_df['Amount']
            .astype(str)
            .str.replace('$', '', regex=False)
            .str.replace(',', '', regex=False)
            .str.strip()
        )

        sanitized_df['Amount'] = pd.to_numeric(
            sanitized_df['Amount'],
            errors='coerce'
        )

        # Remove invalid rows
        sanitized_df = sanitized_df.dropna(subset=['Amount'])

        # Clean categories
        sanitized_df['Category'] = (
            sanitized_df['Category']
            .fillna('Uncategorized')
            .astype(str)
            .str.strip()
            .str.title()
        )

        sanitized_df['Description'] = (
            sanitized_df['Description']
            .fillna('Unknown Transaction')
            .astype(str)
            .str.strip()
        )

        return sanitized_df.reset_index(drop=True)

    except Exception as error_context:

        print(f"❌ Processing Error: {error_context}")
        return None

# =====================================================================
# 💰 WALLET ANALYSIS ENGINE
# =====================================================================

def execute_wallet_allocation_audit(
    cleaned_df: pd.DataFrame
) -> Dict[str, Any]:

    # Separate income vs expenses properly
    income_records = cleaned_df[
        cleaned_df['Category'].str.lower() == 'income'
    ]

    expense_records = cleaned_df[
        cleaned_df['Category'].str.lower() != 'income'
    ]

    total_inflows = float(income_records['Amount'].sum())

    total_outflows = float(expense_records['Amount'].sum())

    # Essential categories
    essential_tags = [
        'Rent',
        'Groceries',
        'Utilities',
        'Transport',
        'Bills'
    ]

    category_aggregates = (
        expense_records
        .groupby('Category')['Amount']
        .sum()
    )

    essential_spend_total = 0.0
    discretionary_spend_total = 0.0

    category_summary_metrics = []

    for category_name, category_total in category_aggregates.items():

        if category_name in essential_tags:
            essential_spend_total += category_total
        else:
            discretionary_spend_total += category_total

        wallet_share_pct = (
            category_total / total_outflows * 100
        ) if total_outflows > 0 else 0

        category_summary_metrics.append({
            'Category': category_name,
            'Total Expended': round(float(category_total), 2),
            'Wallet Share %': round(wallet_share_pct, 1)
        })

    return {
        'net_outflows': total_outflows,
        'net_inflows': total_inflows,
        'essential_allocation': essential_spend_total,
        'discretionary_allocation': discretionary_spend_total,
        'summary_dataframe': pd.DataFrame(category_summary_metrics)
    }

# =====================================================================
# 📊 FINANCIAL INSIGHT ENGINE
# =====================================================================

def generate_financial_recommendations(
    financial_kpis: Dict[str, Any]
) -> str:

    outflows = financial_kpis.get('net_outflows', 0.0)
    inflows = financial_kpis.get('net_inflows', 0.0)
    essential = financial_kpis.get('essential_allocation', 0.0)
    discretionary = financial_kpis.get('discretionary_allocation', 0.0)
    summary_df = financial_kpis.get('summary_dataframe', pd.DataFrame())

    discretionary_pct = (
        discretionary / outflows * 100
    ) if outflows > 0 else 0

    net_savings_margin = inflows - outflows

    report = "# 🏰 Lifestyle Architect Financial Report\n\n"

    report += "## 📊 Spending Overview\n\n"

    report += (
        f"- 💵 Total Income: **${inflows:,.2f}**\n"
    )

    report += (
        f"- 💸 Total Expenses: **${outflows:,.2f}**\n"
    )

    report += (
        f"- 🧱 Essential Spending: **${essential:,.2f}**\n"
    )

    report += (
        f"- 🎯 Discretionary Spending: **${discretionary:,.2f}**\n\n"
    )

    report += (
        f"- 📈 Discretionary Wallet Share: "
        f"**{discretionary_pct:.1f}%**\n\n"
    )

    # Highest category
    if not summary_df.empty:

        highest_row = summary_df.loc[
            summary_df['Total Expended'].idxmax()
        ]

        report += (
            f"## 📌 Largest Spending Category\n\n"
            f"Your highest expense category is "
            f"**{highest_row['Category']}**, consuming "
            f"**{highest_row['Wallet Share %']}%** "
            f"of total expenses.\n\n"
        )

    # Risk assessment
    report += "## 🛑 Financial Risk Assessment\n\n"

    if discretionary_pct > 50:

        report += (
            "⚠️ **Lifestyle Leakage Crisis Detected**\n\n"
            "Your discretionary spending exceeds healthy "
            "student budgeting thresholds.\n\n"
        )

    elif discretionary_pct > 30:

        report += (
            "⚠️ **Moderate Spending Warning**\n\n"
            "Your flexible spending is slightly elevated.\n\n"
        )

    else:

        report += (
            "✅ **Healthy Budget Structure Detected**\n\n"
            "Your spending profile remains financially stable.\n\n"
        )

    # Savings section
    report += "## 💡 Recommendations\n\n"

    if net_savings_margin > 0:

        report += (
            f"1. ✅ Monthly surplus detected: "
            f"**${net_savings_margin:,.2f}**\n\n"
        )

        report += (
            "2. 🏦 Automatically transfer 20% "
            "into savings.\n\n"
        )

    else:

        report += (
            f"1. ❌ Deficit detected: "
            f"**${abs(net_savings_margin):,.2f}**\n\n"
        )

    report += (
        "3. 🍱 Meal prep instead of takeout.\n\n"
        "4. 🎓 Use student discounts wherever possible.\n\n"
        "5. 🚍 Use public transport concessions.\n"
    )

    return report

# =====================================================================
# 🤖 AI CHATBOT
# =====================================================================

def execution_architect_chatbot(user_query: str) -> str:

    if not user_query.strip():

        return (
            "👋 Ask me anything about budgeting, "
            "saving, or student finance!"
        )

    system_persona = (
        "You are The Lifestyle Architect, "
        "a friendly student financial coach. "
        "Give practical budgeting advice."
    )

    # Combine system persona and user query into a single prompt
    full_prompt = f"{system_persona}\n\n{user_query}"

    try:

        ai_response = get_response(
            prompt=full_prompt
        )

        return str(ai_response)

    except Exception as connection_fault:

        return (
            f"⚠️ AI Server Error: {connection_fault}"
        )

# =====================================================================
# 📚 RAG KNOWLEDGE BASE SYSTEM
# =====================================================================

def initialize_and_query_finance_rag(user_question: str):

    docs_directory = "student_knowledge_base"

    os.makedirs(docs_directory, exist_ok=True)

    knowledge_path = os.path.join(
        docs_directory,
        "student_welfare_guidelines.txt"
    )

    welfare_rules_content = """
THE LIFESTYLE ARCHITECT OFFICIAL STUDENT BUDGET MANUAL

RULE-101:
Students should follow the 50/30/20 budgeting rule.

RULE-102:
If discretionary spending exceeds 50%,
the student enters a Lifestyle Leakage Crisis.

RULE-103:
Students should maximize concessions,
discounts, and public transport savings.
"""

    with open(knowledge_path, "w", encoding="utf-8") as file:
        file.write(welfare_rules_content)

    try:

        # IMPORTANT:
        # Replace rag.query if your package uses another name
        retrieved_context = rag.query(
            query=user_question,
            docs_dir=docs_directory,
            k=1
        )

        if isinstance(retrieved_context, list):
            retrieved_context = "\n".join(
                [str(chunk) for chunk in retrieved_context]
            )

        system_persona = (
            "You are The Lifestyle Architect AI coach. "
            "Use ONLY the provided context."
        )

        augmented_prompt = f"""
{system_persona}

Document Context:
{retrieved_context}

Student Question:
{user_question}
"""

        ai_response = get_response(
            prompt=augmented_prompt
        )

        return (
            f"## 📚 Retrieved Knowledge\n\n"
            f"{retrieved_context}\n\n"
            f"---\n\n"
            f"## 🤖 AI Answer\n\n"
            f"{ai_response}"
        )

    except Exception as error:

        return f"❌ RAG System Error: {error}"

# =====================================================================
# 🧪 VALIDATION TESTS
# =====================================================================

print("\n🧪 Running validation tests...")
print("=" * 70)

processed_ledger = load_and_sanitize_statement(
    target_csv_filename
)

assert processed_ledger is not None

assert len(processed_ledger) == 7

assert processed_ledger['Amount'].dtype == 'float64'

financial_kpis = execute_wallet_allocation_audit(
    processed_ledger
)

assert round(
    financial_kpis['essential_allocation'],
    2
) == 569.70

print("✅ ALL VALIDATION TESTS PASSED")

# =====================================================================
# 🌐 GRADIO UI FUNCTIONS
# =====================================================================

def run_financial_audit():

    cleaned_df = load_and_sanitize_statement(
        target_csv_filename
    )

    if cleaned_df is None:
        return "❌ Failed to process statement."

    kpis = execute_wallet_allocation_audit(
        cleaned_df
    )

    report = generate_financial_recommendations(
        kpis
    )

    return report

def run_rag_query(user_question):

    return initialize_and_query_finance_rag(
        user_question
    )

# =====================================================================
# 🌐 GRADIO APPLICATION
# =====================================================================

with gr.Blocks(theme=gr.themes.Soft()) as app:

    gr.Markdown("""
    # 🏰 Lifestyle Architect Financial Intelligence Platform

    ### Features
    - 📊 Transaction Analysis
    - 💰 Wallet Allocation Audit
    - 🤖 AI Financial Coach
    - 📚 RAG Knowledge System
    - 🎓 Student Budget Guidance
    """)

    # =========================================================
    # TAB 1
    # =========================================================
    with gr.Tab("📊 Financial Audit"):

        gr.Markdown(
            "Run a complete financial analysis."
        )

        analyze_btn = gr.Button(
            "Run Financial Audit"
        )

        audit_output = gr.Markdown()

        analyze_btn.click(
            fn=run_financial_audit,
            outputs=audit_output
        )

    # =========================================================
    # TAB 2
    # =========================================================
    with gr.Tab("🤖 AI Financial Coach"):

        chatbot_input = gr.Textbox(
            label="Ask The Lifestyle Architect",
            placeholder=(
                "How can I reduce my spending?"
            )
        )

        chatbot_output = gr.Markdown()

        send_btn = gr.Button("Send")

        send_btn.click(
            fn=execution_architect_chatbot,
            inputs=chatbot_input,
            outputs=chatbot_output
        )

    # =========================================================
    # TAB 3
    # =========================================================
    with gr.Tab("📚 RAG Knowledge Assistant"):

        rag_input = gr.Textbox(
            label="Ask a financial policy question",
            placeholder=(
                "What happens if my discretionary "
                "spending exceeds 50%?"
            )
        )

        rag_output = gr.Markdown()

        rag_btn = gr.Button(
            "Run Knowledge Retrieval"
        )

        rag_btn.click(
            fn=run_rag_query,
            inputs=rag_input,
            outputs=rag_output
        )
def rag_query(question: str):

    try:
        context = rag.query(
            query=question,
            docs_dir="knowledge_base",
            k=1
        )

        if isinstance(context, list):
            context = "\n".join(context)

        full_prompt = f"""
        You are The Lifestyle Architect AI.

        Use ONLY the context below.

        Context:
        {context}

        Question:
        {question}
        """

        response = get_response(full_prompt)

        return f"""
### 📚 Context
{context}

### 🤖 Answer
{response}
"""

    except Exception as e:
        return f"RAG Error: {e}"

# =====================================================================
# 🚀 LAUNCH APPLICATION
# =====================================================================

print("\n🚀 Launching Gradio Application...")
print("=" * 70)

app.launch(debug=True)
# Out:
# ...
# 📑 Generating sample transaction dataset...
# ...
# ✅ CSV dataset saved successfully: student_bank_statement.csv
#
# 🧪 Running validation tests...
# ...
# ✅ ALL VALIDATION TESTS PASSED
# /tmp/ipykernel_4043/3780541497.py:473: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as app:
# 🚀 Launching Gradio Application...
# ...
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://fa320bba2a00ba7776.gradio.live
#
# ...

# %% [markdown]
# ## Custom Financial Tools

# %%
# 🤖 AI Collaboration: Custom Tool Development
# Ask AI to help you create useful financial calculators


def create_savings_calculator_tool():
    """
    Create a custom savings goal calculator as an agent tool

    🤖 AI Collaboration Prompt:
    "Create a savings goal calculator function that takes current savings,
    monthly contribution, and target amount, then calculates time to reach
    goal. Format output for user-friendly display."
    """
    def calculate_savings_goal_timeline(
        current_savings: float,
        monthly_contribution: float,
        target_amount: float
    ) -> str:
        """
        Calculates how long it will take a user to reach a savings goal
        based on current savings and monthly contribution patterns.
        """

        # ----------------------------------------------------------------
        # INPUT VALIDATION
        # ----------------------------------------------------------------
        if current_savings < 0:
            return "❌ Current savings cannot be negative."

        if monthly_contribution <= 0:
            return "❌ Monthly contribution must be greater than $0."

        if target_amount <= 0:
            return "❌ Target amount must be greater than $0."

        if current_savings >= target_amount:
            return (
                "🎉 Congratulations! "
                "You have already reached your savings goal."
            )

        # ----------------------------------------------------------------
        # CALCULATION ENGINE
        # ----------------------------------------------------------------
        remaining_amount = target_amount - current_savings

        months_required = remaining_amount / monthly_contribution

        # Round upward because partial months still require saving
        months_required = int(months_required) + (
            1 if remaining_amount % monthly_contribution != 0 else 0
        )

        years = months_required // 12
        months = months_required % 12

        # ----------------------------------------------------------------
        # USER-FRIENDLY REPORT OUTPUT
        # ----------------------------------------------------------------
        report = "\n🏦 SMART SAVINGS GOAL CALCULATOR\n"
        report += "=" * 60 + "\n\n"

        report += f"💰 Current Savings: ${current_savings:,.2f}\n"
        report += f"📥 Monthly Contribution: ${monthly_contribution:,.2f}\n"
        report += f"🎯 Savings Goal Target: ${target_amount:,.2f}\n\n"

        report += f"📊 Remaining Amount Needed: ${remaining_amount:,.2f}\n"

        # Timeline formatting
        if years > 0:
            report += (
                f"⏳ Estimated Time to Goal: "
                f"{years} year(s) and {months} month(s)\n\n"
            )
        else:
            report += (
                f"⏳ Estimated Time to Goal: "
                f"{months_required} month(s)\n\n"
            )

        # Motivational insight layer
        if months_required <= 6:
            report += (
                "✅ Excellent progress trajectory! "
                "Your savings behaviour is highly efficient.\n"
            )

        elif months_required <= 24:
            report += (
                "📈 Stable savings momentum detected. "
                "Maintaining consistency will achieve your target comfortably.\n"
            )

        else:
            report += (
                "⚠️ Long-term savings horizon detected. "
                "Consider increasing monthly contributions or reducing "
                "discretionary spending leakage to accelerate your goal.\n"
            )

        return report

# %% [markdown]
# ---
#
# # 🧪 STEP 6: Test with a Variety of Data
#
# **🔍 Comprehensive Testing Strategy**
#
# Create thorough tests for your Smart Finance Assistant to ensure it handles real-world scenarios.
#
# ::: {.callout-tip}
# ## 🤖 AI Collaboration for Testing
#
# **Effective Testing Prompts:**
# ```
# "Help me create comprehensive test cases for my finance assistant. Include:
# - Normal transaction data
# - Edge cases (refunds, large amounts, missing data)
# - Invalid data scenarios (corrupted files, wrong formats)
# - Business logic validation (spending calculations, recommendations)
# Create assert statements to verify each scenario."
# ```
# :::
#
# ## Foundation Function Tests

# %%
import pandas as pd
import numpy as np
import io

# =====================================================================
# 1. SETUP: GENERATING TEST DATASETS
# =====================================================================

def create_test_datasets():
    """
    Generates various simulated CSV datasets mirroring real-world
    student financial scenarios and edge cases.
    """
    print("📦 Generating testing datasets...")

    # Dataset 1: Normal Everyday Student Spending
    normal_data = {
        'Date': ['2026-05-01', '2026-05-02', '2026-05-03', '2026-05-04'],
        'Amount': ['$15.50', '$120.00', '$4.50', '$22.00'],
        'Category': ['Food', 'Living', 'Social', 'Transport'],
        'Description': ['Guild Cafe', 'UniLodge Rent', 'Campus Coffee', 'SmartRider']
    }

    # Dataset 2: Edge Cases (Refunds, Extreme Values, Missing Values)
    # Notice the -$50.00 refund, a massive $5000 tuition fee, and a missing Description
    edge_case_data = {
        'Date': ['2026-05-05', '2026-05-06', '2026-05-07', '2026-05-08'],
        'Amount': ['-$50.00', '$5,000.00', '$0.00', '$35.00'],
        'Category': ['Social', 'Education', 'Utility', 'Food'],
        'Description': ['Returned Jeans', 'Curtin Tuition Fees', 'Free Campus Event', np.nan]
    }

    # Dataset 3: Malformed / Invalid Format (Missing the critical 'Amount' column)
    invalid_format_data = {
        'Date': ['2026-05-09'],
        'Cost': ['$10.00'], # The student/bank renamed this column accidentally
        'Category': ['Food'],
        'Description': ['Lunch']
    }

    return (pd.DataFrame(normal_data),
            pd.DataFrame(edge_case_data),
            pd.DataFrame(invalid_format_data))


# =====================================================================
# 2. MODULE TESTS
# =====================================================================

def test_data_loading_function(df_normal, df_edge, df_invalid):
    """
    Validates that data cleaning strips string formatting ($ and ,)
    and handles bad columns gracefully.
    """
    print("🧪 Testing data loading and cleaning logic...")

    # Test A: Normal data cleaning validation
    cleaned_normal = load_and_clean_transaction_data(df_normal)
    assert cleaned_normal is not None, "Bug: Normal data failed to load."
    assert cleaned_normal['Amount'].dtype in [np.float64, np.int64], "Bug: Amount column wasn't converted to numbers."
    assert cleaned_normal['Amount'].iloc[1] == 120.00, "Bug: Dollar sign was not stripped correctly."

    # Test B: Edge case characters validation (commas and negative numbers)
    cleaned_edge = load_and_clean_transaction_data(df_edge)
    assert cleaned_edge['Amount'].iloc[0] == -50.00, "Bug: Negative refund amounts are broken."
    assert cleaned_edge['Amount'].iloc[1] == 5000.00, "Bug: Commas in large numbers break cleaning."
    assert cleaned_edge['Description'].isna().sum() == 1, "Bug: Failed to maintain missing fields safely."

    # Test C: Invalid data structure validation
    cleaned_invalid = load_and_clean_transaction_data(df_invalid)
    assert cleaned_invalid is None, "Bug: System should return None if required columns are missing."
    print("   👉 Data loading & cleaning tests: PASSED")


def test_spending_analysis(df_normal, df_edge):
    """
    Validates business math calculations and category distributions.
    """
    print("🧪 Testing spending mathematical analysis calculations...")

    cleaned_normal = load_and_clean_transaction_data(df_normal)
    cleaned_edge = load_and_clean_transaction_data(df_edge)

    # Combine normal and edge cases to test math on mixed types
    combined_df = pd.concat([cleaned_normal, cleaned_edge], ignore_index=True)

    # Check Math Logic
    positive_spending = combined_df[combined_df['Amount'] > 0]['Amount'].sum()
    total_refunds = abs(combined_df[combined_df['Amount'] < 0]['Amount'].sum())

    # Ensure manual math calculations match system variables exactly
    assert positive_spending == 5162.00, f"Bug: Expected positive spend $5162.00, got ${positive_spending}"
    assert total_refunds == 50.00, f"Bug: Expected refund total $50.00, got ${total_refunds}"
    print("   👉 Spending analysis math tests: PASSED")


def test_business_insights(df_normal):
    """
    Validates that the advice engine flags budgets accurately.
    """
    print("🧪 Testing automated business rule insights generation...")

    cleaned_normal = load_and_clean_transaction_data(df_normal)

    # Force a high-spending social environment to check if the warning triggers
    high_social_data = {
        'Date': ['2026-05-10', '2026-05-11'],
        'Amount': ['$200.00', '$50.00'],
        'Category': ['Social', 'Living'],
        'Description': ['Party Venue', 'Groceries']
    }
    df_high_social = load_and_clean_transaction_data(pd.DataFrame(high_social_data))

    # Test A: Checking if the budget warning triggers when over 30% spending is Social
    report_warning = analyze_spending_patterns(df_high_social, savings_goal=10.0)
    assert "High Discretionary Alert" in report_warning, "Bug: Advice engine failed to flag excessive social spending."

    # Test B: Checking if the healthy tag triggers for conservative spending
    report_healthy = analyze_spending_patterns(cleaned_normal, savings_goal=10.0)
    assert "Excellent Budgeting" in report_healthy, "Bug: System flagged a clean budget erroneously."
    print("   👉 Business insights rule tests: PASSED")


# =====================================================================
# 3. RUNNING THE COMPLETE SUITE
# =====================================================================

print("🔍 INITIALIZING LIFESTYLE ARCHITECT AUTOMATED TEST MATRIX")
print("=" * 60)

try:
    # 1. Initialize data
    normal_df, edge_df, invalid_df = create_test_datasets()
    print("-" * 60)

    # 2. Run test modules
    test_data_loading_function(normal_df, edge_df, invalid_df)
    test_spending_analysis(normal_df, edge_df)
    test_business_insights(normal_df)

    print("=" * 60)
    print("✅ SUCCESS: All functional test scenarios passed verification checks!")
    print("Ready for GitHub deployment and Developer's Diary evidence capture.")

except AssertionError as e:
    print("\n=" * 60)
    print(f"❌ CRITICAL TEST SUITE FAILURE: {e}")
    print("Please inspect your logic functions before continuing.")
except Exception as e:
    print(f"⚠️ UNEXPECTED EXCEPTION DURING RUNTIME: {e}")

# %% [markdown]
# ## Advanced Integration Tests

# %%
import pandas as pd
import numpy as np
import gradio as gr
from hands_on_ai.chat import get_response

# =====================================================================
# 1. END-TO-END PIPELINE WORKFLOW TEST
# =====================================================================

def test_full_workflow():
    """
    Simulates a full user journey: Data Loading -> Analysis -> AI Interaction.
    Verifies that information correctly flows across system boundaries.
    """
    print("🧪 Testing full workflow pipeline integration...")

    # Step A: Create valid mock student data
    mock_data = {
        'Date': ['2026-05-15', '2026-05-16'],
        'Amount': ['$30.00', '$200.00'],
        'Category': ['Food', 'Social'],
        'Description': ['Campus Lunch', 'Concert Ticket']
    }
    df = pd.DataFrame(mock_data)

    # Step B: Pass data from loader directly into the analysis calculator
    cleaned_df = load_and_clean_transaction_data(df)
    assert cleaned_df is not None, "Integration Breakpoint: Cleaner failed inside workflow pipeline."

    report = analyze_spending_patterns(cleaned_df, savings_goal=50.0)
    assert "Financial Report" in report, "Integration Breakpoint: Calculator failed to compile report string."
    print("   👉 Internal Data Pipeline: Functional")

    # Step C: Verify live external network connection to the AI Server
    print("   📡 Testing live server connection via hands-on-ai...")
    try:
        test_prompt = "Quickly verify connection. Reply with one word: Active."
        ai_response = get_response(test_prompt)
        assert len(ai_response) > 0, "Server responded with an empty string."
        print(f"   👉 Server Network Pipeline: Functional (AI Response: '{ai_response.strip()}')")
    except Exception as network_error:
        raise AssertionError(f"Network Pipeline Broken: Cannot reach Ollama server. Check API Key. Detail: {network_error}")


# =====================================================================
# 2. INTERFACE ERROR HANDLING & RESILIENCE TEST
# =====================================================================

def test_ui_error_handling():
    """
    Simulates user mistakes on the Gradio interface frontend to ensure
    the application fails gracefully with friendly alerts instead of crashing.
    """
    print("🧪 Testing interface error boundaries & resilience rules...")

    # Scenario A: User presses 'Generate' without uploading any file
    # We will test our Gradio interface wrapper directly
    def interface_wrapper_test(file, goal):
        if file is None:
            return "### ⚠️ Missing Input: Please upload a valid CSV file before analyzing."
        data = load_and_clean_transaction_data(file)
        return analyze_spending_patterns(data, savings_goal=goal)

    empty_input_result = interface_wrapper_test(None, 100.0)
    assert "Missing Input" in empty_input_result, "Bug: UI failed to trigger a warning message when file input is missing."

    # Scenario B: User inputs a negative numbers goal or string typo
    # Our analysis engine should handle extreme goal targets gracefully
    crazy_goal_result = interface_wrapper_test(pd.DataFrame({
        'Date': ['2026-05-10'], 'Amount': ['$10.00'], 'Category': ['Living'], 'Description': ['Rent']
    }), goal=-9999.0)
    assert "Financial Report" in crazy_goal_result, "Bug: Negative financial targets caused a system exception."

    print("   👉 User Interface Resilience Tests: PASSED")


# =====================================================================
# 3. RUNNING THE SYSTEM INTEGRATION MATRIX
# =====================================================================

print("🔍 RUNNING LIFESTYLE ARCHITECT SYSTEM INTEGRATION MATRIX")
print("=" * 60)

try:
    test_full_workflow()
    print("-" * 60)
    test_ui_error_handling()
    print("=" * 60)
    print("✅ INTEGRATION SUCCESS: Complete system components are communicating cleanly!")
    print("Your app infrastructure is ready for milestone submission.")

except AssertionError as integration_error:
    print("\n=" * 60)
    print(f"❌ INTEGRATION BREAKDOWN: {integration_error}")
    print("Review component connection logic ports.")
except Exception as unexpected_err:
    print(f"⚠️ UNEXPECTED SYSTEM FAULT: {unexpected_err}")

# %% [markdown]
# ---
#
# # 📊 Project Completion Checklist
#
# ## Foundation Skills ✅
# - [ ] **Data Processing**: CSV loading and cleaning functions work reliably
# - [ ] **Analysis Functions**: Spending summaries calculate correctly
# - [ ] **Business Insights**: Recommendations are relevant and actionable
# - [ ] **Error Handling**: Graceful handling of data issues
# - [ ] **Testing**: Comprehensive test coverage for core functions
# - [ ] **Documentation**: Clear AI collaboration documentation in diary
#
# ## Advanced Integration ✅
# - [ ] **Chat Interface**: Finance advisor personality implemented
# - [ ] **RAG System**: Document retrieval for financial guidance
# - [ ] **Custom Tools**: At least one financial calculator/utility
# - [ ] **Gradio UI**: Professional, user-friendly interface
# - [ ] **Full Integration**: All components work together seamlessly
#
# ## Professional Standards ✅
# - [ ] **Code Quality**: Professional, commented, maintainable code
# - [ ] **Business Focus**: Clear connection to real finance problems
# - [ ] **User Experience**: Interface suitable for non-technical users
# - [ ] **AI Collaboration**: Extensive, well-documented AI usage
# - [ ] **Testing**: Robust validation of all features
#
# ## Project Documentation ✅
# - [ ] **Developer's Diary**: Complete AI collaboration documentation
# - [ ] **README**: Clear project description and usage instructions
# - [ ] **GitHub**: Regular commits showing development progress
# - [ ] **Reflection**: Thoughtful analysis of learning and challenges
#
# ---
#
# # 🎯 Final Thoughts: Your Finance Assistant Journey
#
# Congratulations on building your Smart Finance Assistant! This project represents a significant achievement in modern business programming:
#
# **Technical Skills Developed:**
# - AI-assisted development workflows
# - Professional data processing with pandas
# - Integration of multiple AI technologies
# - User interface design with Gradio
# - Comprehensive software testing
#
# **Business Skills Developed:**
# - Financial data analysis and insights
# - User-centered application design
# - Professional documentation practices
# - Iterative development methodology
# - Critical evaluation of AI suggestions
#
# **Professional Preparation:**
# - Experience with industry-standard AI collaboration
# - Portfolio-ready application development
# - Understanding of business problem-solving with technology
# - Documentation practices for workplace environments
#
# **Your Smart Finance Assistant demonstrates your ability to direct AI tools toward meaningful business solutions - exactly the skill set that modern BIS graduates need for career success!**
#
# ---
#
# *Remember to document all AI collaborations in your Developer's Diary and maintain regular GitHub commits throughout your development process.*
